# %% [markdown]
# # Exception

# %%
#Handle ZeroDivisionError Exception
#Write a Python program to handle a ZeroDivisionError exception
#when dividing a number by zero.
def exception(a,b):
    try:
        print(a/b)
    except:
        print("cant divide by zero")
a=int(input())
b=int(input())
exception(a,b)
# Out:
#  10
#  0
# cant divide by zero

# %%
#Validate Integer Input and Raise ValueError
#Write a Python program that prompts the user to input an integer
#and raises a ValueError exception if the input is not a valid integer.
def validation(n):
    try:
        num=int(n)
        print(num)
    except:
        raise ValueError("Invalid Integer")
n=input()
validation(n)
# Out:
#  abc
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 6, in validation(n)
#       5 try:
# ----> 6     num=int(n)
#       7     print(num)
#
# ValueError: invalid literal for int() with base 10: 'abc'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 11
#       9         raise ValueError("Invalid Integer")
#      10 n=input()
# ---> 11 validation(n)
#
# Cell In[4], line 9, in validation(n)
#       7     print(num)
#       8 except:
# ----> 9     raise ValueError("Invalid Integer")
#
# ValueError: Invalid Integer

# %%
#Handle FileNotFoundError Exception When Opening a File
#Write a Python program that opens a file and handles a
#FileNotFoundError exception if the file does not exist.
def openfile(file):
    try:
        f1=open(file,"r")
        print(f1.read())

    except:
        print("File not found")
file=input()
openfile(file)
# Out:
#  mytxt.txt
# File not found

# %%
#Validate Numerical Inputs and Raise TypeError
#Write a Python program that prompts the user to input two numbers
#and raises a TypeError exception if the inputs are not numerical.
def numerical(a,b):
    print(int(a))
    print(int(b))
try:
    a=input()
    b=input()
    numerical(a,b)
except:
    print("Please enter a valid input")
# Out:
#  abc
#  2
# Please enter a valid input

# %%
#Handle IndexError in List Operations
#Write a Python program that executes an operation on a list and
#handles an IndexError exception if the index is out of range.
def listoperations(lst,n):
    try:
        print(lst[n])
    except:
        print("Index out of range")
lst=[1,2,3,4,5]
n=int(input())
listoperations(lst,n)
# Out:
#  7
# Index out of range

# %%
#Handle ArithmeticError Exception in Division
#Write a Python program that executes division and handles an
#ArithmeticError exception if there is an arithmetic error.
def division(a,b):
    try:
        print(a/b)
    except ArithmeticError:
        print("Arithmetic Error")
a=int(input())
b=int(input())
division(a,b)
# Out:
#  10
#  0
# Arithmetic Error

# %%
#Handle UnicodeDecodeError When Opening a File
#Write a Python program that opens a file and handles a
#UnicodeDecodeError exception if there is an encoding issue.
def openfile(file):
    try:
        f1=open(file,"r")
        print(f1.read())
        f1.close()
    except UnicodeDecodeError:
        print("UniCode Decode Error")
file=input()
openfile(file)
# Out:
#  file.txt
# 10
# abc
# 30

# %%
#Handle AttributeError Exception in List Operations
#Write a Python program that executes a list operation and handles
#an AttributeError exception if the attribute does not exist.
def listoperation(lst):
    try:
        lst.hello()
    except AttributeError:
        print("Attribute error")
lst=[1,2,3,4,5]
listoperation(lst)
# Out:
# Attribute error
